# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (2.8.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/paddock_valuator/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
import sys
from pathlib import Path
from datetime import date

CWD = Path().resolve()
PROJECT_ROOT = CWD.parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.data.supabase_client import (
    fetch_vehicle_by_id,
    upsert_vehicle_timeseries_point,
)
from src.inference.valuation_service import ValuatorEngine

vehicle_id = "f60fab60-3d2d-4fdd-b29b-240b685b3cc3"
vehicle = fetch_vehicle_by_id(vehicle_id)
vehicle

# 2) Run valuation (LLM-based for now)
engine = ValuatorEngine()
valuation = engine.evaluate(vehicle)

print("Estimated value (USD):", valuation.price_usd)
print("Comment:\n", valuation.comment)

# 3) Upsert into vehicle_timeseries for TODAY
today = date.today()
mileage = vehicle.get("mileage") if vehicle else None

result = upsert_vehicle_timeseries_point(
    vehicle_id=vehicle_id,
    value=valuation.price_usd,
    mileage=mileage,
    at_date=today,
)

print("Timeseries upsert result:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 if str(PROJECT_ROOT) not in sys.path:
#       8     sys.path.append(str(PROJECT_ROOT))
# ---> 10 from src.data.supabase_client import (
#      11     fetch_vehicle_by_id,
#      12     upsert_vehicle_timeseries_point,
#      13 )
#      14 from src.inference.valuation_service import ValuatorEngine
#      16 vehicle_id = "f60fab60-3d2d-4fdd-b29b-240b685b3cc3"
#
# File ~/Paddock/Asset/Valuation/src/data/supabase_client.py:48
#      39     rows = response.data or []
#      40     return rows[0] if rows else None
#      42 def upsert_vehicle_timeseries_point(
#      43     vehicle_id: str,
#      44     value: float,
#      45     mileage: Optional[float] = None,
#      46     at_date: Optional[date] = None,
#      47     table_name: str = "vehicle_timeseries",
# ---> 48 ) -> Dict[str, Any]:
#      49     """
#      50     Insert or update a timeseries point for a given vehicle and date.
#      51
#    (...)     60     Returns a small dict describing what happened.
#      61     """
#      62     from datetime import date as _date  # avoid shadowing
#
# NameError: name 'Any' is not defined

# %%
engine = ValuatorEngine()
result = engine.evaluate(vehicle)

print("Estimated value (USD):", result.price_usd)
print("Comment:\n", result.comment)
